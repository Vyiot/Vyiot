# %% [markdown]
# <a href="https://colab.research.google.com/github/Vyiot/Vyiot/blob/main/labeldata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')  # Chọn tài khoản và Allow

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -q selenium webdriver-manager

# %%
from pathlib import Path

# Thư mục gốc trên Drive để lưu dữ liệu
MY_FOLDER = "Colab_Selenium_Data"   # <- đổi tên nếu muốn
BASE_DIR = Path("/content/drive/MyDrive") / MY_FOLDER
BASE_DIR.mkdir(parents=True, exist_ok=True)

print("Save to:", BASE_DIR)
